# %%
from utils import *
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import numpy as np

# %%
rate , data = wavfile.read('../data/sample1.wav')

show_spec_from_sample(data , rate)

# %%
for crop in crop_sample(data, rate):
    show_spec_from_sample(crop,rate)
