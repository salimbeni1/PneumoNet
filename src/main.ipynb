# %%
from sound_processing import *

# dependency on librosa !! pip install librosa

# %%
features, diseases, positions, controls, frequences, patientnbs = get_feature_and_labels( '../data/train/*/*/*'  ) # both control and case

indx = 2 # example on sample nb100

print(features[indx] ,diseases[indx] , positions[indx] , controls[indx] , frequences[indx] , patientnbs[indx])

# 110250
# Out:
# 100%|██████████| 532/532 [03:35<00:00,  2.46it/s]
# [[-0.00070312 -0.00068402 -0.00059652 ...  0.00748672  0.00750835
#    0.00752581]
#  [-0.00842162 -0.00844162 -0.00845693 ...  0.01215653  0.01203572
#    0.01191186]
#  [-0.00083441 -0.00081648 -0.00079718 ... -0.00062419 -0.00043239
#   -0.00024917]
#  [ 0.00120548  0.00123065  0.00125043 ... -0.00235686 -0.00229653
#   -0.00223493]] Pn P3 Ca 22050 10

# %%
for f in features:
    print(f.shape)
# Out:
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (12, 110250)
# (6, 110250)
# (6, 110250)
# (4, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (10, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (6, 110250)
# (4, 110250)
# (2, 110250)
# (2, 110250)
# (8, 110250)
# (2, 110250)
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (4, 110250)
# (2, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (4, 110250)
# (8, 110250)
# (2, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (6, 110250)
# (2, 110250)
# (2, 110250)
# (6, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (8, 110250)
# (8, 110250)
# (12, 110250)
# (6, 110250)
# (8, 110250)
# (4, 110250)
# (12, 110250)
# (4, 110250)
# (6, 110250)
# (8, 110250)
# (2, 110250)
# (6, 110250)
# (4, 110250)
# (6, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (2, 110250)
# (8, 110250)
# (2, 110250)
# (4, 110250)
# (8, 110250)
# (6, 110250)
# (10, 110250)
# (8, 110250)
# (6, 110250)
# (8, 110250)
# (2, 110250)
# (4, 110250)
# (8, 110250)
# (6, 110250)
# (8, 110250)
# (8, 110250)
# (8, 110250)
# (4, 110250)
# (14, 110250)
# (10, 110250)
# (20, 110250)
# (8, 110250)
# (10, 110250)
# (8, 110250)
# (8, 110250)
# (2, 110250)
# (10, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (6, 110250)
# (4, 110250)
# (6, 110250)
# (8, 110250)
# (6, 110250)
# (6, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (8, 110250)
# (4, 110250)
# (4, 110250)
# (8, 110250)
# (6, 110250)
# (10, 110250)
# (2, 110250)
# (4, 110250)
# (8, 110250)
# (2, 110250)
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (8, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (10, 110250)
# (8, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (6, 110250)
# (8, 110250)
# (4, 110250)
# (6, 110250)
# (6, 110250)
# (6, 110250)
# (8, 110250)
# (6, 110250)
# (8, 110250)
# (10, 110250)
# (6, 110250)
# (2, 110250)
# (4, 110250)
# (6, 110250)
# (2, 110250)
# (10, 110250)
# (14, 110250)
# (8, 110250)
# (14, 110250)
# (10, 110250)
# (8, 110250)
# (10, 110250)
# (16, 110250)
# (4, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (8, 110250)
# (2, 110250)
# (6, 110250)
# (10, 110250)
# (4, 110250)
# (6, 110250)
# (6, 110250)
# (4, 110250)
# (10, 110250)
# (18, 110250)
# (10, 110250)
# (10, 110250)
# (10, 110250)
# (8, 110250)
# (8, 110250)
# (4, 110250)
# (8, 110250)
# (12, 110250)
# (4, 110250)
# (8, 110250)
# (4, 110250)
# (8, 110250)
# (6, 110250)
# (6, 110250)
# (2, 110250)
# (2, 110250)
# (10, 110250)
# (12, 110250)
# (12, 110250)
# (12, 110250)
# (6, 110250)
# (14, 110250)
# (12, 110250)
# (4, 110250)
# (8, 110250)
# (8, 110250)
# (12, 110250)
# (10, 110250)
# (4, 110250)
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (8, 110250)
# (8, 110250)
# (8, 110250)
# (6, 110250)
# (2, 110250)
# (2, 110250)
# (4, 110250)
# (6, 110250)
# (6, 110250)
# (8, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (8, 110250)
# (12, 110250)
# (12, 110250)
# (2, 110250)
# (10, 110250)
# (8, 110250)
# (4, 110250)
# (10, 110250)
# (10, 110250)
# (8, 110250)
# (12, 110250)
# (2, 110250)
# (2, 110250)
# (2, 110250)
# (6, 110250)
# (2, 110250)
# (2, 110250)
# (6, 110250)
# (6, 110250)
# (10, 110250)
# (8, 110250)
# (10, 110250)
# (12, 110250)
# (8, 110250)
# (4, 110250)
# (10, 110250)
# (10, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (8, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (8, 110250)
# (2, 110250)
# (6, 110250)
# (4, 110250)
# (8, 110250)
# (4, 110250)
# (4, 110250)
# (8, 110250)
# (8, 110250)
# (8, 110250)
# (13, 110250)
# (13, 110250)
# (13, 110250)
# (10, 110250)
# (12, 110250)
# (13, 110250)
# (12, 110250)
# (8, 110250)
# (20, 110250)
# (8, 110250)
# (10, 110250)
# (6, 110250)
# (2, 110250)
# (10, 110250)
# (14, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (45, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (22, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (45, 110250)
# (2, 110250)
# (2, 110250)
# (4, 110250)
# (14, 110250)
# (4, 110250)
# (2, 110250)
# (4, 110250)
# (4, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (20, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (22, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (4, 110250)
# (6, 110250)
# (6, 110250)
# (4, 110250)
# (4, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (21, 110250)
# (24, 110250)
# (24, 110250)
# (25, 110250)
# (28, 110250)
# (22, 110250)
# (24, 110250)
# (22, 110250)
# (24, 110250)
# (6, 110250)
# (2, 110250)
# (4, 110250)
# (14, 110250)
# (4, 110250)
# (8, 110250)
# (4, 110250)
# (8, 110250)
# (21, 110250)
# (24, 110250)
# (25, 110250)
# (24, 110250)
# (25, 110250)
# (24, 110250)
# (28, 110250)
# (28, 110250)
# (6, 110250)
# (2, 110250)
# (4, 110250)
# (14, 110250)
# (4, 110250)
# (8, 110250)
# (4, 110250)
# (8, 110250)
# (24, 110250)
# (22, 110250)
# (24, 110250)
# (24, 110250)
# (24, 110250)
# (26, 110250)
# (28, 110250)
# (25, 110250)
# (24, 110250)
# (22, 110250)
# (25, 110250)
# (25, 110250)
# (25, 110250)
# (24, 110250)
# (25, 110250)
# (21, 110250)
# (22, 110250)
# (22, 110250)
# (22, 110250)
# (21, 110250)
# (22, 110250)
# (22, 110250)
# (24, 110250)

# %%
for sample in features[indx]:
    mfcc = features_extraction(sample,22050,'mfcc')
    mfcc = normalize(mfcc, 'minmax')
    print(mfcc.shape)
# Out:
# (32, 216)
# (32, 216)
# (32, 216)
# (32, 216)

# %%
for sample in features[indx]:
    display_all(sample,22050)
# Out:
# C:\Anaconda3\envs\my_env\lib\site-packages\librosa\display.py:974: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# C:\Anaconda3\envs\my_env\lib\site-packages\librosa\display.py:974: MatplotlibDeprecationWarning: The 'linthreshy' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# C:\Anaconda3\envs\my_env\lib\site-packages\librosa\display.py:974: MatplotlibDeprecationWarning: The 'linscaley' parameter of __init__() has been renamed 'linscale' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
