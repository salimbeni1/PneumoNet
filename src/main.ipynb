# %%
from sound_processing import *

# %%
features, diseases, positions, controls, frequences, patientnbs = get_feature_and_labels( '../data/*/*/*/'  ) # both control and case

indx = 100 # example on sample nb100

print(features[indx] ,diseases[indx] , positions[indx] , controls[indx] , frequences[indx] , patientnbs[indx])
# Out:
# [[-0.0003012  -0.00037361 -0.00044671 ... -0.00089455 -0.00077571
#   -0.00065062]
#  [ 0.00475092  0.00483186  0.0049139  ... -0.00074303 -0.00054193
#   -0.00033917]] Pn P4 Ca 22050 26

# %%
for sample in features[indx]:
    #show_spec_from_sample(sample , frequences[indx])
    mfcc = features_extraction(sample,22050,'mfcc')
    mfcc = normalize(mfcc, 'minmax')
    print(mfcc.shape)
# Out:
# (32, 216)
# (32, 216)

# %%
for sample in features[indx]:
    display_all(sample,22050)
# Out:
# (32, 216)
# (32, 216)
